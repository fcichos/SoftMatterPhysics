# %% [markdown]
# # Introduction

# %% [markdown]
# <img src="img/intro.png" alt="intro" name="intro" class="bg-primary mb-1" width="800px">

# %% [markdown]
# [Lecture Slides](https://home.uni-leipzig.de/~physik/sites/mona/teaching/periodic-lectures/soft-matter-physics-ws-2021-22/)
